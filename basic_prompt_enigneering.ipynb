# %% [markdown]
# <a href="https://colab.research.google.com/github/hbetabessi/prompt_engineering_techniques/blob/main/basic_prompt_enigneering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Setup
# LLM: Groq's free api endpoint (Groq API Key)
#
# LLM Framework: LangChain

# %% [markdown]
# Install required libraries

# %%
# !pip install -q -U langchain-groq>=0.2.4
# !pip install -q -U langchain-core




print("✅ Dependencies installed!")
# Out:
# ✅ Dependencies installed!

# %% [markdown]
# Import related libraries

# %%
import os
import getpass

from langchain_groq import ChatGroq
from langchain_core.prompts import ChatPromptTemplate, PromptTemplate

# %%
os.environ["GROQ_API_KEY"] = getpass.getpass()

print("✅ Setup complete!")
# Out:
# ··········
# ✅ Setup complete!

# %%
llm = ChatGroq(
    model="llama-3.1-8b-instant",
    temperature=0.5
)

# %%
chat_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "You are a helpful assistant that explains problems step-by-step."),
        ("human", "Solve this problem step by step: {input}"),
    ]
)

chain = chat_prompt | llm

# %%
ai_msg = chain.invoke({"input": "Provide me python code of sudoku"})
print(ai_msg.content)
# Out:
# **Sudoku Solver in Python**
#
# Sudoku is a 9x9 grid divided into nine 3x3 sub-grids or "regions." Some numbers are already filled in, while others are blank. The goal is to fill in the blank cells with numbers from 1 to 9 such that each row, column, and region contains each number exactly once.
#
# **Step 1: Define the Sudoku Grid**
#
# We'll start by defining the Sudoku grid as a 2D list in Python. We'll use zeros to represent blank cells.
#
# ```python
# # Define the Sudoku grid
# sudoku_grid = [
#     [5, 3, 0, 0, 7, 0, 0, 0, 0],
#     [6, 0, 0, 1, 9, 5, 0, 0, 0],
#     [0, 9, 8, 0, 0, 0, 0, 6, 0],
#     [8, 0, 0, 0, 6, 0, 0, 0, 3],
#     [4, 0, 0, 8, 0, 3, 0, 0, 1],
#     [7, 0, 0, 0, 2, 0, 0, 0, 6],
#     [0, 6, 0, 0, 0, 0, 2, 8, 0],
#     [0, 0, 0, 4, 1, 9, 0, 0, 5],
#     [0, 0, 0, 0, 8, 0, 0, 7, 9]
# ]
# ```
#
# **Step 2: Define a Function to Check Validity**
#
# ...
